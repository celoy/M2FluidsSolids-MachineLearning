# %% [markdown]
# # Hands-on Lesson 8 - Value iteration corrected
#
# The goal of this tutorial is to implement the **Value Iteration** algorithm in a simple grid world.

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# To play animations
from matplotlib.animation import FuncAnimation
from IPython.display import display, HTML

# %% [markdown]
# ## The environment
#
# We create the class **GridWorld**, which is a $N \times N$ grid with a starting cell at the coordinate $[0, 0]$ and
#
# - hole cells that terminate the episode with a punishment
# - obstacle cells that cannot be entered
# - goal cells that terminate the episode with a reward
#
# There are four possible actions at each grid cell (down, up, right, left) that correspond to the integers between 0 and 3.
#
# Entering a grid cell gives a reward (possibly negative):
#
# - normal grid cells give -1
# - holes give -10
# - goals give +10
#
# Three matrices are created as variables of the class *GridWorld*:
#
# - **map** is used to represent the different cell types graphically
#     - -1: holes (r = - 10, terminal state)
#     - 0: start state
#     - 1: normal grid cell (r = -1)
#     - 2: obstacles (not reachable)
#     - 3: goal (r = 10, terminal state)
# - **rewards** is used to store the rewards gained when entering a cell
# - **terminal** is a boolean matrix with True on terminal states (goals or holes) and False otherwise

# %%
class GridWorld():
    def __init__(self, N, goals=[], holes=[], obstables=[]):
        # scalar variables
        self.N = N
        self.Nstates = N**2
        self.Nactions = 4

        # matrices
        self.map = np.ones((N, N), dtype=int)
        self.rewards = -np.ones((N, N), dtype=int)
        self.terminal = np.zeros((N,N), dtype=bool)
        
        # adding particular cells in matrices
        self._add_start()
        self._add_goals(goals)
        self._add_holes(holes)
        self._add_obstacles(obstables)
        
        # calculating the transition matrix 
        self._calculate_transition_matrix()
        
        # placing the agent in the start state
        self.reset()
        
    def reset(self):
        self.agent = [0, 0]
        self.agentarchive = [self.agent]        
        
    def step(self, a):
        # move the agent according to the transition matrix
        s = self._coord_to_state(self.agent)
        s_ = self.transition_matrix[s, a]
        self.agent = self._state_to_coord(s_)
        self.agentarchive.append(self.agent)
        
        # calculate the reward and determines if a terminal state has been reached
        coord_ = tuple(self.agent)
        r = self.rewards[coord_]
        if self.terminal[coord_]:
            done = True
        else:
            done = False
        return s_, r, done
    
    def get_current_state(self):
        return self._coord_to_state(self.agent)
    
    def get_coord(self, s):
        return self._state_to_coord(s)

    def get_reward(self, s):
        return self.rewards[tuple(self._state_to_coord(s))]

    def get_terminal(self, s):
        return self.terminal[tuple(self._state_to_coord(s))]     
    
    #__ internal functions _____________________
    def _coord_to_state(self, coord):
        row = coord[0]
        col = coord[1]
        return row * self.N + col
        
    def _state_to_coord(self, state):
        row = state // self.N
        col = state %  self.N
        return [row, col]
    
    def _add_start(self):
        self.map[0, 0] = 0
    
    def _add_goals(self, goals):
        for goal in goals:
            self.map[tuple(goal)] = 3
            self.rewards[tuple(goal)] = 10
            self.terminal[tuple(goal)] = True
            
    def _add_holes(self, holes):
        for hole in holes:
            self.map[tuple(hole)] = -1
            self.rewards[tuple(hole)] = -10
            self.terminal[tuple(hole)] = True
            
    def _add_obstacles(self, obstacles):
        for obstacle in obstacles:
            self.map[tuple(obstacle)] = 2
            
    #__ transition matrix: s_ = T(s,a) _____________________            
    def _calculate_transition_matrix(self):
        T = np.zeros((self.Nstates, self.Nactions), dtype=int)
        for s in range(self.Nstates):
            coord = self._state_to_coord(s)
            row = coord[0]
            col = coord[1]
            
            # a = 0 (DOWN)
            row0 = min(row + 1, self.N - 1)
            if self.map[row0, col] == 2:
                T[s,0] = s
            else:
                T[s,0] = self._coord_to_state([row0, col])
 
            # a = 1 (UP)
            row1 = max(row - 1, 0)
            if self.map[row1, col] == 2:
                T[s,1] = s
            else:
                T[s,1] = self._coord_to_state([row1, col])

            # a = 2 (RIGHT)
            col2 = min(col + 1, self.N - 1)
            if self.map[row, col2] == 2:
                T[s,2] = s
            else:
                T[s,2] = self._coord_to_state([row, col2])
            
            # a = 3 (LEFT)
            col3 = max(col - 1, 0)
            if self.map[row, col3] == 2:
                T[s,3] = s
            else:
                T[s,3] = self._coord_to_state([row, col3])
            
        self.transition_matrix = T      
        
    #__ rendering animation ________________________________            
    def render(self):
        fig, ax = plt.subplots()
        ax.imshow(self.map, cmap='gist_earth')
        agentdata, = ax.plot([],[],'or')
        ax.grid(False)
        ax.set_xlabel('columns')
        ax.set_ylabel('rows')

        def animate(i):
            agentdata.set_data(self.agentarchive[i][1], self.agentarchive[i][0])
            ax.set_title('time: %3d' % i)
            return agentdata,

        anim = FuncAnimation(
            fig, 
            animate,
            frames=len(self.agentarchive),
            interval=500,
            blit=True
        ) 
        return anim

# %% [markdown]
# Here is an example of the usage of the class *GridWorld*.
#
# First an instance of the class is created, by passing as arguments:
# - the size *N* of the grid world
# - the list of goals (a list of [row, col]-coordinates)
# - the list of holes
# - the list of obstacles
#
# The grid can be rendered using the function **render()**.

# %%
# PARAMETERS
N = 5
GOALS = [
    [4, 4]
]
HOLES = [
    [3, 0],
    [2, 3],
    [1, 2],    
]
OBSTACLES = [
    [2, 0],
    [3, 3],    
    [4, 3],    
]

# Creation of the grid and rendering
mygrid = GridWorld(N, goals=GOALS, holes=HOLES, obstables=OBSTACLES)

anim = mygrid.render()
display(HTML(anim.to_jshtml()))
plt.close()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img1e30571722bb4ae2b71d00bf45635912">
#   <div class="anim-controls">
#     <input id="_anim_slider1e30571722bb4ae2b71d00bf45635912" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim1e30571722bb4ae2b71d00bf45635912.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim1e30571722bb4ae2b71d00bf45635912.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim1e30571722bb4ae2b71d00bf45635912.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim1e30571722bb4ae2b71d00bf45635912.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim1e30571722bb4ae2b71d00bf45635912.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim1e30571722bb4ae2b71d00bf45635912.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim1e30571722bb4ae2b71d00bf45635912.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim1e30571722bb4ae2b71d00bf45635912.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim1e30571722bb4ae2b71d00bf45635912.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim1e30571722bb4ae2b71d00bf45635912.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select1e30571722bb4ae2b71d00bf45635912"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_1e30571722bb4ae2b71d00bf45635912"
#              >
#       <label for="_anim_radio1_1e30571722bb4ae2b71d00bf45635912">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_1e30571722bb4ae2b71d00bf45635912"
#              checked>
#       <label for="_anim_radio2_1e30571722bb4ae2b71d00bf45635912">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_1e30571722bb4ae2b71d00bf45635912"
#              >
#       <label for="_anim_radio3_1e30571722bb4ae2b71d00bf45635912">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img1e30571722bb4ae2b71d00bf45635912";
#     var slider_id = "_anim_slider1e30571722bb4ae2b71d00bf45635912";
#     var loop_select_id = "_anim_loop_select1e30571722bb4ae2b71d00bf45635912";
#     var frames = new Array(1);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/YYfK9AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAA

# %% [markdown]
# We can now use the function **step(action)** to move an agent randomly on the grid.
#
# Here, state is an integer between 0 (the starting state) and $N^2$.
#
# The function **step(action)** returns the new state, the reward received, and a boolean indicating if the episode is finished.

# %%
mygrid.reset()
s = mygrid.get_current_state()
done = False

while not done:
    action = np.random.randint(mygrid.Nactions)  # random action
    s_, r, done = mygrid.step(action)
    print("s: %3d  |  a: %1d  |  r: %3d  |  s_: %3d" % (s, action, r, s_))
    s = s_
    
anim = mygrid.render()
display(HTML(anim.to_jshtml()))
plt.close()
# Out:
# s:   0  |  a: 1  |  r:  -1  |  s_:   0
# s:   0  |  a: 0  |  r:  -1  |  s_:   5
# s:   5  |  a: 1  |  r:  -1  |  s_:   0
# s:   0  |  a: 2  |  r:  -1  |  s_:   1
# s:   1  |  a: 3  |  r:  -1  |  s_:   0
# s:   0  |  a: 2  |  r:  -1  |  s_:   1
# s:   1  |  a: 2  |  r:  -1  |  s_:   2
# s:   2  |  a: 0  |  r: -10  |  s_:   7
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img4a46c52417964fc5a290206f9e57b029">
#   <div class="anim-controls">
#     <input id="_anim_slider4a46c52417964fc5a290206f9e57b029" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim4a46c52417964fc5a290206f9e57b029.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim4a46c52417964fc5a290206f9e57b029.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim4a46c52417964fc5a290206f9e57b029.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim4a46c52417964fc5a290206f9e57b029.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim4a46c52417964fc5a290206f9e57b029.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim4a46c52417964fc5a290206f9e57b029.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim4a46c52417964fc5a290206f9e57b029.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim4a46c52417964fc5a290206f9e57b029.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim4a46c52417964fc5a290206f9e57b029.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim4a46c52417964fc5a290206f9e57b029.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select4a46c52417964fc5a290206f9e57b029"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_4a46c52417964fc5a290206f9e57b029"
#              >
#       <label for="_anim_radio1_4a46c52417964fc5a290206f9e57b029">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_4a46c52417964fc5a290206f9e57b029"
#              checked>
#       <label for="_anim_radio2_4a46c52417964fc5a290206f9e57b029">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_4a46c52417964fc5a290206f9e57b029"
#              >
#       <label for="_anim_radio3_4a46c52417964fc5a290206f9e57b029">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4a46c52417964fc5a290206f9e57b029";
#     var slider_id = "_anim_slider4a46c52417964fc5a290206f9e57b029";
#     var loop_select_id = "_anim_loop_select4a46c52417964fc5a290206f9e57b029";
#     var frames = new Array(9);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/YYfK9AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAA

# %% [markdown]
# ### Questions
#
# 1. Play with the environment to create alternative maps
# 2. Implement a deterministic policy by imposing a sequence of actions

# %%
# Question 1
N = 10
GOALS = [
    [0, 8],
    [5, 2],
    [6, 6],    
]
HOLES = [
    [3, 0],
    [7, 3],
    [1, 5],    
]
OBSTACLES = [
    [2, 0],
    [3, 3],    
    [4, 3],    
    [4, 9],    
    [1, 8],    
    [7, 2],    
    [7, 7],    
    [8, 9],    
    [9, 5],    
]

# Creation of the grid and rendering
mygrid = GridWorld(N, goals=GOALS, holes=HOLES, obstables=OBSTACLES)

anim = mygrid.render()
display(HTML(anim.to_jshtml()))
plt.close()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img06b19d4908724952aa7c50478a8b3a3e">
#   <div class="anim-controls">
#     <input id="_anim_slider06b19d4908724952aa7c50478a8b3a3e" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim06b19d4908724952aa7c50478a8b3a3e.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim06b19d4908724952aa7c50478a8b3a3e.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim06b19d4908724952aa7c50478a8b3a3e.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim06b19d4908724952aa7c50478a8b3a3e.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim06b19d4908724952aa7c50478a8b3a3e.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim06b19d4908724952aa7c50478a8b3a3e.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim06b19d4908724952aa7c50478a8b3a3e.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim06b19d4908724952aa7c50478a8b3a3e.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim06b19d4908724952aa7c50478a8b3a3e.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim06b19d4908724952aa7c50478a8b3a3e.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select06b19d4908724952aa7c50478a8b3a3e"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_06b19d4908724952aa7c50478a8b3a3e"
#              >
#       <label for="_anim_radio1_06b19d4908724952aa7c50478a8b3a3e">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_06b19d4908724952aa7c50478a8b3a3e"
#              checked>
#       <label for="_anim_radio2_06b19d4908724952aa7c50478a8b3a3e">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_06b19d4908724952aa7c50478a8b3a3e"
#              >
#       <label for="_anim_radio3_06b19d4908724952aa7c50478a8b3a3e">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img06b19d4908724952aa7c50478a8b3a3e";
#     var slider_id = "_anim_slider06b19d4908724952aa7c50478a8b3a3e";
#     var loop_select_id = "_anim_loop_select06b19d4908724952aa7c50478a8b3a3e";
#     var frames = new Array(1);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/YYfK9AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAA

# %%
# Question 2
mygrid.reset()
s = mygrid.get_current_state()
done = False
action_sequence = [0, 2, 0, 0, 0, 3]  # 0 down; 1 up: 2 right; 3 left

for i in range(len(action_sequence)):
    action = action_sequence[i]  # random action
    s_, r, done = mygrid.step(action)
    print("s: %3d  |  a: %1d  |  r: %3d  |  s_: %3d" % (s, action, r, s_))
    s = s_
    
anim = mygrid.render()
display(HTML(anim.to_jshtml()))
plt.close()
# Out:
# s:   0  |  a: 0  |  r:  -1  |  s_:  10
# s:  10  |  a: 2  |  r:  -1  |  s_:  11
# s:  11  |  a: 0  |  r:  -1  |  s_:  21
# s:  21  |  a: 0  |  r:  -1  |  s_:  31
# s:  31  |  a: 0  |  r:  -1  |  s_:  41
# s:  41  |  a: 3  |  r:  -1  |  s_:  40
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img0797d34156f145b584ea1d8fef6e1905">
#   <div class="anim-controls">
#     <input id="_anim_slider0797d34156f145b584ea1d8fef6e1905" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim0797d34156f145b584ea1d8fef6e1905.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim0797d34156f145b584ea1d8fef6e1905.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim0797d34156f145b584ea1d8fef6e1905.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim0797d34156f145b584ea1d8fef6e1905.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim0797d34156f145b584ea1d8fef6e1905.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim0797d34156f145b584ea1d8fef6e1905.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim0797d34156f145b584ea1d8fef6e1905.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim0797d34156f145b584ea1d8fef6e1905.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim0797d34156f145b584ea1d8fef6e1905.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim0797d34156f145b584ea1d8fef6e1905.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select0797d34156f145b584ea1d8fef6e1905"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_0797d34156f145b584ea1d8fef6e1905"
#              >
#       <label for="_anim_radio1_0797d34156f145b584ea1d8fef6e1905">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_0797d34156f145b584ea1d8fef6e1905"
#              checked>
#       <label for="_anim_radio2_0797d34156f145b584ea1d8fef6e1905">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_0797d34156f145b584ea1d8fef6e1905"
#              >
#       <label for="_anim_radio3_0797d34156f145b584ea1d8fef6e1905">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0797d34156f145b584ea1d8fef6e1905";
#     var slider_id = "_anim_slider0797d34156f145b584ea1d8fef6e1905";
#     var loop_select_id = "_anim_loop_select0797d34156f145b584ea1d8fef6e1905";
#     var frames = new Array(7);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/YYfK9AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAA

# %% [markdown]
# ## The value iteration algorithm
#
# The value iteration algorithm is used to evaluate the state-value $v_\pi(s)$ of a given policy $\pi(a|s)$.
#
# The steps of value iteration are the following:
# - the values are initialized with $v_0(s)=0$ for all states $s$
# - for all states, we update the value with an iterative procedure
#
# $$v_{k+1}(s) = \sum_a \pi(a|s) \left(\mathcal{R}^a_s + \gamma \sum_{s'} \mathcal{P}^a_{ss'} v_k(s')\right)$$
#
# - This iterative procedure is repeated until $\| v_{k+1} - v_{k}\|_\infty < \epsilon$
#
# In our case, the iterative procedure can be simplified because we use a discount $\gamma = 1$ and because the transition are deterministic with $s' = T(s,a)$, such that
#
# $$v_{k+1}(s) = \sum_a \pi(a|s) \left(\mathcal{R}^a_s + v_k(T(s,a))\right)$$

# %%
class ValueIteration():
    def __init__(self, env):
        self.Nstates = env.Nstates
        self.env = env
        self.reset()
        
    def reset(self):    
        self.values = np.zeros(self.Nstates)
        self.valuemap = [self._create_map()]

    def iterate(self, policy):
        new_values = np.zeros(self.Nstates)
        for s in range(self.Nstates):
            if not self.env.get_terminal(s):
                r = 0
                vk = 0
                for a in range(self.env.Nactions):
                    s_ = self.env.transition_matrix[s, a]
                    r += policy[s,a] * self.env.get_reward(s_)
                    vk += policy[s,a] * self.values[s_]
                new_values[s] = r + vk
        norm_inf = np.max(np.abs(new_values - self.values))
        self.values = new_values
        self.valuemap.append(self._create_map())
        return norm_inf  
    
    def _create_map(self):
        mymap = np.zeros((self.env.N,self.env.N))
        for s in range(self.Nstates):
            mymap[tuple(self.env.get_coord(s))] = self.values[s]
        return mymap    
    
    #__ rendering animation ________________________________            
    def render(self):
        fig, ax = plt.subplots()
        mapdata = ax.imshow(
            self.valuemap[0], 
            vmin = -15,
            vmax = +10,
            cmap='gist_earth',
            animated=True
        )
        cbar = fig.colorbar(mapdata, ax=ax)
        cbar.set_label('value v(s)')
        ax.grid(False)
        ax.set_xlabel('columns')
        ax.set_ylabel('rows')

        def animate(i):
            mapdata.set_array(self.valuemap[i])
            ax.set_title('iteration: %3d' % i)
            return mapdata,

        anim = FuncAnimation(
            fig, 
            animate,
            frames=len(self.valuemap),
            interval=500,
            blit=True
        ) 
        return anim

# %% [markdown]
# The policy $\pi(s|a)$ is stored in the matrix **policy** of size **(mygrid.Nstates, mygrid.Nactions)**.
#
# ### Questions
# 1. Write a random policy using the matrix **policy**
# 2. Write a simple function to assess that the policy is a probability function (probabilities should sum to 1 for each state)
# 3. Write the Value Iteration algorithm using the class **ValueIteration**
# 4. Plot the evolution of the values with the function **render()**

# %%
# Question 1
random_policy = np.ones((mygrid.Nstates, mygrid.Nactions)) / mygrid.Nactions

# %%
# Question 2
def check_policy(policy):
    assert np.all(policy>= 0), "probablities are not positive"
    assert np.all(np.sum(policy, axis=-1)==1), "probabilities do not sum to 1"
    print("policy is a probability function")

# %%
check_policy(random_policy)
# Out:
# policy is a probability function

# %%
# Question 3
# PARAMETERS
N = 5
GOALS = [
    [4, 4]
]
HOLES = [
    [3, 0],
    [2, 3],
    [1, 2],    
]
OBSTACLES = [
    [2, 0],
    [3, 3],    
    [4, 3],    
]

# Creation of the grid and rendering
mygrid = GridWorld(N, goals=GOALS, holes=HOLES, obstables=OBSTACLES)

myVI = ValueIteration(mygrid)
convergence = False
epsilon = 0.1

while not convergence:
    norm = myVI.iterate(random_policy)
    print(norm)
    if norm < epsilon:
        convergence = True
# Out:
# 5.5
# 3.25
# 2.015625
# 1.65625
# 1.576171875
# 1.414794921875
# 1.3250732421875
# 1.198333740234375
# 1.1317863464355469
# 1.0599842071533203
# 0.9923627376556396
# 0.9259510636329651
# 0.8630953878164291
# 0.803116999566555
# 0.7465588552877307
# 0.6932043062988669
# 0.6431093660648912
# 0.5961315916501917
# 0.5521852678211872
# 0.5111307430752277
# 0.47283926449154023
# 0.4371680768515489
# 0.4039777883568121
# 0.37312745745837006
# 0.34447970413426177
# 0.3179001453934376
# 0.29325909777763215
# 0.2704317461053769
# 0.24929875068928453
# 0.22974638708781825
# 0.21166672017660204
# 0.1949576065173808
# 0.17952266061831068
# 0.16527114513306174
# 0.15211782675527985
# 0.139982795031532
# 0.128791260019689
# 0.11847333274277361
# 0.10896379607214612
# 0.10020186999818037
# 0.09213097552991911

# %%
# Question 4
anim = myVI.render()
display(HTML(anim.to_jshtml()))
plt.close()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imga75142f02358402b9441438ab15968f4">
#   <div class="anim-controls">
#     <input id="_anim_slidera75142f02358402b9441438ab15968f4" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anima75142f02358402b9441438ab15968f4.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anima75142f02358402b9441438ab15968f4.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anima75142f02358402b9441438ab15968f4.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anima75142f02358402b9441438ab15968f4.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anima75142f02358402b9441438ab15968f4.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anima75142f02358402b9441438ab15968f4.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anima75142f02358402b9441438ab15968f4.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anima75142f02358402b9441438ab15968f4.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anima75142f02358402b9441438ab15968f4.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anima75142f02358402b9441438ab15968f4.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selecta75142f02358402b9441438ab15968f4"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_a75142f02358402b9441438ab15968f4"
#              >
#       <label for="_anim_radio1_a75142f02358402b9441438ab15968f4">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_a75142f02358402b9441438ab15968f4"
#              checked>
#       <label for="_anim_radio2_a75142f02358402b9441438ab15968f4">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_a75142f02358402b9441438ab15968f4"
#              >
#       <label for="_anim_radio3_a75142f02358402b9441438ab15968f4">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imga75142f02358402b9441438ab15968f4";
#     var slider_id = "_anim_slidera75142f02358402b9441438ab15968f4";
#     var loop_select_id = "_anim_loop_selecta75142f02358402b9441438ab15968f4";
#     var frames = new Array(42);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/YYfK9AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpA

# %% [markdown]
# ## Policy iteration
#
# From the approximation of $v_k \approx v_\pi(s)$ given by the value iteration algorithm, we can construct a greedy policy:
#
# $$a = \pi(s) = \mathrm{argmax}_a \left[\mathcal{R}^a_s + \gamma \sum_{s'} \mathcal{P}^a_{ss'} v_k(s')\right]$$
#
# which simplifies into
#
# $$a = \pi(s) = \mathrm{argmax}_a \left[\mathcal{R}^a_s + v_k(T(s,a))\right]$$
#
#
# The value of this new policy can then be estimated with value iteration. An so on...
#
# ### Questions
# 1. From the value matrix, construct the greedy policy matrix
# 2. Evaluate the value of this new policy
# 3. Iterate on value iteration and policy iteration to converge towards $v^*(s)$ and $\pi^*(s)$ (what is a good indication of convergence?)
# 4. Plot the motion of the agent using the policy $\pi^*(s)$

# %%
# Question 1
def build_greedy_policy(env, VI):
    policy = np.zeros((env.Nstates, env.Nactions))
    for s in range(env.Nstates):
        if env.get_terminal(s):
            policy[s, 0] = 1
        else:
            q = np.zeros(env.Nactions)
            for a in range(env.Nactions):
                s_ = env.transition_matrix[s, a]
                q[a] = env.get_reward(s_) + VI.values[s_]
            greedy_action = np.argmax(q)
            policy[s, greedy_action] = 1
    return policy

# %%
# Question 2
greedy_policy = build_greedy_policy(mygrid, myVI)

myVI.reset()
convergence = False
epsilon = 0.1

while not convergence:
    norm = myVI.iterate(greedy_policy)
    if norm < epsilon:
        convergence = True

anim = myVI.render()
display(HTML(anim.to_jshtml()))
plt.close()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img53a2d4ef78f64e528e05b48f86cfb225">
#   <div class="anim-controls">
#     <input id="_anim_slider53a2d4ef78f64e528e05b48f86cfb225" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim53a2d4ef78f64e528e05b48f86cfb225.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim53a2d4ef78f64e528e05b48f86cfb225.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim53a2d4ef78f64e528e05b48f86cfb225.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim53a2d4ef78f64e528e05b48f86cfb225.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim53a2d4ef78f64e528e05b48f86cfb225.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim53a2d4ef78f64e528e05b48f86cfb225.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim53a2d4ef78f64e528e05b48f86cfb225.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim53a2d4ef78f64e528e05b48f86cfb225.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim53a2d4ef78f64e528e05b48f86cfb225.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim53a2d4ef78f64e528e05b48f86cfb225.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select53a2d4ef78f64e528e05b48f86cfb225"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_53a2d4ef78f64e528e05b48f86cfb225"
#              >
#       <label for="_anim_radio1_53a2d4ef78f64e528e05b48f86cfb225">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_53a2d4ef78f64e528e05b48f86cfb225"
#              checked>
#       <label for="_anim_radio2_53a2d4ef78f64e528e05b48f86cfb225">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_53a2d4ef78f64e528e05b48f86cfb225"
#              >
#       <label for="_anim_radio3_53a2d4ef78f64e528e05b48f86cfb225">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img53a2d4ef78f64e528e05b48f86cfb225";
#     var slider_id = "_anim_slider53a2d4ef78f64e528e05b48f86cfb225";
#     var loop_select_id = "_anim_loop_select53a2d4ef78f64e528e05b48f86cfb225";
#     var frames = new Array(6);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/YYfK9AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAA

# %%
# Question 3
N_policy_iteration_max = 10

# random policy
policy = np.ones((mygrid.Nstates, mygrid.Nactions)) / mygrid.Nactions

for i in range(N_policy_iteration_max):
    myVI.reset()
    convergence = False
    epsilon = 0.1

    j=0
    while not convergence:
        j +=1
        norm = myVI.iterate(policy)
        print("policy iteration", i, "value iteration", j, "convergence", norm)
        if norm < epsilon:
            convergence = True
            
    greedy_policy = build_greedy_policy(mygrid, myVI)

    if np.allclose(greedy_policy, policy):
        break
    else:
        policy = greedy_policy
# Out:
# policy iteration 0 value iteration 1 convergence 5.5
# policy iteration 0 value iteration 2 convergence 3.25
# policy iteration 0 value iteration 3 convergence 2.015625
# policy iteration 0 value iteration 4 convergence 1.65625
# policy iteration 0 value iteration 5 convergence 1.576171875
# policy iteration 0 value iteration 6 convergence 1.414794921875
# policy iteration 0 value iteration 7 convergence 1.3250732421875
# policy iteration 0 value iteration 8 convergence 1.198333740234375
# policy iteration 0 value iteration 9 convergence 1.1317863464355469
# policy iteration 0 value iteration 10 convergence 1.0599842071533203
# policy iteration 0 value iteration 11 convergence 0.9923627376556396
# policy iteration 0 value iteration 12 convergence 0.9259510636329651
# policy iteration 0 value iteration 13 convergence 0.8630953878164291
# policy iteration 0 value iteration 14 convergence 0.803116999566555
# policy iteration 0 value iteration 15 convergence 0.7465588552877307
# policy iteration 0 value iteration 16 convergence 0.6932043062988669
# policy iteration 0 value iteration 17 convergence 0.6431093660648912
# policy iteration 0 value iteration 18 convergence 0.5961315916501917
# policy iteration 0 value iteration 19 convergence 0.5521852678211872
# policy iteration 0 value iteration 20 convergence 0.5111307430752277
# policy iteration 0 value iteration 21 convergence 0.47283926449154023
# policy iteration 0 value iteration 22 convergence 0.4371680768515489
# policy iteration 0 value iteration 23 convergence 0.4039777883568121
# policy iteration 0 value iteration 24 convergence 0.37312745745837006
# policy iteration 0 value iteration 25 convergence 0.34447970413426177
# policy iteration 0 value iteration 26 convergence 0.3179001453934376
# policy iteration 0 value iteration 27 convergence 0.29325909777763215
# policy iteration 0 value iteration 28 convergence 0.2704317461053769
# policy iteration 0 value iteration 29 convergence 0.24929875068928453
# policy iteration 0 value iteration 30 convergence 0.22974638708781825
# policy iteration 0 value iteration 31 convergence 0.21166672017660204
# policy iteration 0 value iteration 32 convergence 0.1949576065173808
# policy iteration 0 value iteration 33 convergence 0.17952266061831068
# policy iteration 0 value iteration 34 convergence 0.16527114513306174
# policy iteration 0 value iteration 35 convergence 0.15211782675527985
# policy iteration 0 value iteration 36 convergence 0.139982795031532
# policy iteration 0 value iteration 37 convergence 0.128791260019689
# policy iteration 0 value iteration 38 convergence 0.11847333274277361
# policy iteration 0 value iteration 39 convergence 0.10896379607214612
# policy iteration 0 value iteration 40 convergence 0.10020186999818037
# policy iteration 0 value iteration 41 convergence 0.09213097552991911
# policy iteration 1 value iteration 1 convergence 10.0
# policy iteration 1 value iteration 2 convergence 10.0
# policy iteration 1 value iteration 3 convergence 10.0
# policy iteration 1 value iteration 4 convergence 10.0
# policy iteration 1 value iteration 5 convergence 0.0
# policy iteration 2 value iteration 1 convergence 10.0
# policy iteration 2 value iteration 2 convergence 10.0
# policy iteration 2 value iteration 3 convergence 10.0
# policy iteration 2 value iteration 4 convergence 10.0
# policy iteration 2 value iteration 5 convergence 10.0
# policy iteration 2 value iteration 6 convergence 0.0
# policy iteration 3 value iteration 1 convergence 10.0
# policy iteration 3 value iteration 2 convergence 10.0
# policy iteration 3 value iteration 3 convergence 10.0
# policy iteration 3 value iteration 4 convergence 10.0
# policy iteration 3 value iteration 5 convergence 10.0
# policy iteration 3 value iteration 6 convergence 10.0
# policy iteration 3 value iteration 7 convergence 0.0
# policy iteration 4 value iteration 1 convergence 10.0
# policy iteration 4 value iteration 2 convergence 10.0
# policy iteration 4 value iteration 3 convergence 10.0
# policy iteration 4 value iteration 4 convergence 10.0
# policy iteration 4 value iteration 5 convergence 10.0
# policy iteration 4 value iteration 6 convergence 10.0
# policy iteration 4 value iteration 7 convergence 10.0
# policy iteration 4 value iteration 8 convergence 0.0
# policy iteration 5 value iteration 1 convergence 10.0
# policy iteration 5 value iteration 2 convergence 10.0
# policy iteration 5 value iteration 3 convergence 10.0
# policy iteration 5 value iteration 4 convergence 10.0
# policy iteration 5 value iteration 5 convergence 10.0
# policy iteration 5 value iteration 6 convergence 10.0
# policy iteration 5 value iteration 7 convergence 10.0
# policy iteration 5 value iteration 8 convergence 10.0
# policy iteration 5 value iteration 9 convergence 10.0
# policy iteration 5 value iteration 10 convergence 0.0
# policy iteration 6 value iteration 1 convergence 10.0
# policy iteration 6 value iteration 2 convergence 10.0
# policy iteration 6 value iteration 3 convergence 10.0
# policy iteration 6 value iteration 4 convergence 10.0
# policy iteration 6 value iteration 5 convergence 10.0
# policy iteration 6 value iteration 6 convergence 10.0
# policy iteration 6 value iteration 7 convergence 10.0
# policy iteration 6 value iteration 8 convergence 10.0
# policy iteration 6 value iteration 9 convergence 10.0
# policy iteration 6 value iteration 10 convergence 10.0
# policy iteration 6 value iteration 11 convergence 0.0
# policy iteration 7 value iteration 1 convergence 10.0
# policy iteration 7 value iteration 2 convergence 10.0
# policy iteration 7 value iteration 3 convergence 10.0
# policy iteration 7 value iteration 4 convergence 10.0
# policy iteration 7 value iteration 5 convergence 10.0
# policy iteration 7 value iteration 6 convergence 10.0
# policy iteration 7 value iteration 7 convergence 10.0
# policy iteration 7 value iteration 8 convergence 10.0
# policy iteration 7 value iteration 9 convergence 10.0
# policy iteration 7 value iteration 10 convergence 10.0
# policy iteration 7 value iteration 11 convergence 10.0
# policy iteration 7 value iteration 12 convergence 10.0
# policy iteration 7 value iteration 13 convergence 0.0
# policy iteration 8 value iteration 1 convergence 10.0
# policy iteration 8 value iteration 2 convergence 10.0
# policy iteration 8 value iteration 3 convergence 10.0
# policy iteration 8 value iteration 4 convergence 10.0
# policy iteration 8 value iteration 5 convergence 10.0
# policy iteration 8 value iteration 6 convergence 10.0
# policy iteration 8 value iteration 7 convergence 10.0
# policy iteration 8 value iteration 8 convergence 10.0
# policy iteration 8 value iteration 9 convergence 10.0
# policy iteration 8 value iteration 10 convergence 10.0
# policy iteration 8 value iteration 11 convergence 10.0
# policy iteration 8 value iteration 12 convergence 10.0
# policy iteration 8 value iteration 13 convergence 0.0

# %%
# Question 4
mygrid.reset()
s = mygrid.get_current_state()
done = False

while not done:
    action =  np.argmax(policy[s])
    s_, r, done = mygrid.step(action)
    print("s: %3d  |  a: %1d  |  r: %3d  |  s_: %3d" % (s, action, r, s_))
    s = s_
    
anim = mygrid.render()
display(HTML(anim.to_jshtml()))
plt.close()
# Out:
# s:   0  |  a: 2  |  r:  -1  |  s_:   1
# s:   1  |  a: 2  |  r:  -1  |  s_:   2
# s:   2  |  a: 2  |  r:  -1  |  s_:   3
# s:   3  |  a: 0  |  r:  -1  |  s_:   8
# s:   8  |  a: 2  |  r:  -1  |  s_:   9
# s:   9  |  a: 0  |  r:  -1  |  s_:  14
# s:  14  |  a: 0  |  r:  -1  |  s_:  19
# s:  19  |  a: 0  |  r:  10  |  s_:  24
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img4d0bc4901e1e44a1b528897f8e1eb836">
#   <div class="anim-controls">
#     <input id="_anim_slider4d0bc4901e1e44a1b528897f8e1eb836" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim4d0bc4901e1e44a1b528897f8e1eb836.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim4d0bc4901e1e44a1b528897f8e1eb836.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim4d0bc4901e1e44a1b528897f8e1eb836.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim4d0bc4901e1e44a1b528897f8e1eb836.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim4d0bc4901e1e44a1b528897f8e1eb836.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim4d0bc4901e1e44a1b528897f8e1eb836.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim4d0bc4901e1e44a1b528897f8e1eb836.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim4d0bc4901e1e44a1b528897f8e1eb836.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim4d0bc4901e1e44a1b528897f8e1eb836.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim4d0bc4901e1e44a1b528897f8e1eb836.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select4d0bc4901e1e44a1b528897f8e1eb836"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_4d0bc4901e1e44a1b528897f8e1eb836"
#              >
#       <label for="_anim_radio1_4d0bc4901e1e44a1b528897f8e1eb836">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_4d0bc4901e1e44a1b528897f8e1eb836"
#              checked>
#       <label for="_anim_radio2_4d0bc4901e1e44a1b528897f8e1eb836">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_4d0bc4901e1e44a1b528897f8e1eb836"
#              >
#       <label for="_anim_radio3_4d0bc4901e1e44a1b528897f8e1eb836">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4d0bc4901e1e44a1b528897f8e1eb836";
#     var slider_id = "_anim_slider4d0bc4901e1e44a1b528897f8e1eb836";
#     var loop_select_id = "_anim_loop_select4d0bc4901e1e44a1b528897f8e1eb836";
#     var frames = new Array(9);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/YYfK9AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAA

# %% [markdown]
# ### Questions
# 1. What are the drawbacks of this method?
# 2. How could it be improved?
